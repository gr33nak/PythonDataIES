# %%
import requests
import pandas as pd
import time

# %% [markdown]
# # Seminar - APIs and real-life coding

# %% [markdown]
# # Task 1: Requesting API
# # 1a. Create a function requesting data from sreality
#
# ```python
# base_url = 'https://www.sreality.cz/api/cs/v2/estates?category_main_cb=1&category_type_cb=1&locality_region_id=10&per_page60&page={}'.format(
#     i)
#
# r = requests.get(base_url)
# d = r.json()
# ```
#
# * function should parametrize:
#     * `category_main_cb` - `{'flat': 1, 'house': 2, 'land': 3}`
#     * `category_type_cb` - `{'sell': 1, 'rent': 2}`
#     * `locality_region_id` - `{'Praha': 10, 'Brno': 14}`
#     * `page` parameter
# * use string inputs for `category_main_cb` and `category_type_cb`
# * test the validity of inputs
# * include try/except clause to handle errors
# * function should return JSON data in python types
# * do not forget to sleep each request at least 0.5s

# %%
def sreality(category_main, category_type, category_region, page):
    mains = {'flat':1, 'house':2, 'land':3}
    type = {"sell":1, "rent":2}
    location = {"Praha":10, "Brno":14}

    base_url = f'https://www.sreality.cz/api/cs/v2/estates?category_main_cb={mains[category_main]}&category_type_cb={type[category_type]}&locality_region_id={location[category_region]}&per_page60&page={page}'

    try:
        r = requests.get(base_url)
        if r.ok:
            return r.json()
    except:
        print("There was an erron in request.")

sreality("house", "rent", "Praha", 1)
# Out:
# {'meta_description': '236 realit v nabídce pronájem domů a nemovitostí Praha. Vyberte si novou nemovitost na sreality.cz s hledáním na mapě a velkými náhledy fotografií nabízených domů a nemovitostí.',
#  'result_size': 236,
#  '_embedded': {'estates': [{'labelsReleased': [['new_building'],
#      ['school', 'drugstore']],
#     'has_panorama': 0,
#     'labels': ['Novostavba', 'Škola 1 min. pěšky', 'Lékárna 3 min. pěšky'],
#     'is_auction': False,
#     'labelsAll': [['new_building', 'garage'],
#      ['playground',
#       'small_shop',
#       'vet',
#       'tavern',
#       'theater',
#       'candy_shop',
#       'movies',
#       'atm',
#       'tram',
#       'sports',
#       'kindergarten',
#       'train',
#       'restaurant',
#       'bus_public_transport',
#       'shop',
#       'school',
#       'drugstore',
#       'medic',
#       'post_office',
#       'metro']],
#     'seo': {'category_main_cb': 2,
#      'category_sub_cb': 39,
#      'category_type_cb': 2,
#      'locality': 'praha-praha-nebusice-'},
#     'exclusively_at_rk': 0,
#     'category': 2,
#     'has_floor_plan': 0,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/2663527500',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/2663527500',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'YT-Luxury-Property-luxusni-byty-Praha-Praha-Nove-Mesto',
#       'id': 20710,
#       'name': 'Y&T Luxury Property – luxusní byty Praha',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_G_I/WK7Fdo.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 6 - Praha-Nebušice',
#     'has_video': False,
#     'advert_images_count': 9,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 2,
#     'hash_id': 2663527500,
#     'attractive_offer': 0,
#     'price': 45000,
#     'price_czk': {'value_raw': 45000,
#      'unit': 'za měsíc',
#      'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_Ks/mm4Bx4a.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_Ks/mm4Bx4a.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/0?category_main_cb=2&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=2'},
#      'self': {'href': '/cs/v2/estates/2663527500?region_tip=2453123'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_Ks/mm4Bx4a.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_Jy/8sXB3f7.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_Kx/lD8BsZr.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_Kx/aBcBsZs.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_Jy/2MQ8i0.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jb/Xg18eT.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_Ks/mm4Bx4a.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Pronájem  vily 276\xa0m², pozemek 1\xa0168\xa0m²',
#     'region_tip': 2453123,
#     'gps': {'lat': 50.104434601667776, 'lon': 14.338530398332225},
#     'has_matterport_url': False},
#    {'labelsReleased': [['new_building'], ['train', 'post_office']],
#     'has_panorama': 0,
#     'labels': ['Novostavba', 'Vlak 2 min. pěšky', 'Pošta 7 min. pěšky'],
#     'is_auction': False,
#     'labelsAll': [['new_building', 'parking_lots', 'not_furnished'],
#      ['playground',
#       'natural_attraction',
#       'theater',
#       'small_shop',
#       'candy_shop',
#       'vet',
#       'movies',
#       'tavern',
#       'sightseeing',
#       'post_office',
#       'bus_public_transport',
#       'train',
#       'restaurant',
#       'kindergarten',
#       'metro',
#       'school',
#       'shop',
#       'sports',
#       'atm',
#       'drugstore',
#       'tram',
#       'medic']],
#     'seo': {'category_main_cb': 2,
#      'category_sub_cb': 37,
#      'category_type_cb': 2,
#      'locality': 'praha-jinonice-na-hutmance'},
#     'exclusively_at_rk': 0,
#     'category': 2,
#     'has_floor_plan': 0,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/2058085964',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/2058085964',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'ENGEL-VOLKERS-Praha-Smichov',
#       'id': 10628,
#       'name': 'ENGEL & VÖLKERS',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_H_H/g1qQpu.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 5 - Jinonice',
#     'has_video': False,
#     'advert_images_count': 18,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 2,
#     'hash_id': 2058085964,
#     'attractive_offer': 0,
#     'price': 62000,
#     'price_czk': {'value_raw': 62000,
#      'unit': 'za měsíc',
#      'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_Ky/LeIHjE.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_Ky/LeIHjE.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/1?category_main_cb=2&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=2'},
#      'self': {'href': '/cs/v2/estates/2058085964'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_Ky/LeIHjE.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_Jz/89tSkI.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_Jy/2pZBdwE.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_LZ/pMa3WW.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QR_L6/dBZBeDp.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_Jh/6ylBeFU.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_Ky/LeIHjE.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Pronájem  rodinného domu 156\xa0m², pozemek 302\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.04868260166777, 'lon': 14.376078398332224},
#     'has_matterport_url': False},
#    {'labelsReleased': [[], []],
#     'has_panorama': 0,
#     'labels': [],
#     'is_auction': False,
#     'labelsAll': [['garage', 'not_furnished', 'cellar'],
#      ['small_shop',
#       'movies',
#       'candy_shop',
#       'theater',
#       'playground',
#       'vet',
#       'tavern',
#       'natural_attraction',
#       'train',
#       'drugstore',
#       'shop',
#       'metro',
#       'school',
#       'kindergarten',
#       'sports',
#       'restaurant',
#       'bus_public_transport',
#       'atm',
#       'medic',
#       'tram',
#       'post_office']],
#     'seo': {'category_main_cb': 2,
#      'category_sub_cb': 39,
#      'category_type_cb': 2,
#      'locality': 'praha-ruzyne-nad-visnovkou'},
#     'exclusively_at_rk': 0,
#     'category': 2,
#     'has_floor_plan': 0,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/1356421468',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/1356421468',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False}},
#     'paid_logo': 0,
#     'locality': 'Praha 6 - Ruzyně',
#     'has_video': False,
#     'advert_images_count': 30,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 2,
#     'hash_id': 1356421468,
#     'attractive_offer': 0,
#     'price': 59000,
#     'price_czk': {'value_raw': 59000,
#      'unit': 'za měsíc',
#      'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gU_k/cFWg1S.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gU_k/cFWg1S.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/2?category_main_cb=2&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=2'},
#      'self': {'href': '/cs/v2/estates/1356421468'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gU_k/cFWg1S.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gW_k/Za5hND.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gS_l/X6NhdC.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gW_k/SJDhNE.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gV_n/0UUgVB.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gT_m/vizhSE.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gU_k/cFWg1S.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Pronájem  vily 236\xa0m², pozemek 600\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.07071260166777, 'lon': 14.324121398332224},
#     'has_matterport_url': False},
#    {'labelsReleased': [[], []],
#     'has_panorama': 0,
#     'labels': [],
#     'is_auction': False,
#     'labelsAll': [['garage', 'parking_lots', 'not_furnished'],
#      ['playground',
#       'candy_shop',
#       'small_shop',
#       'movies',
#       'tavern',
#       'theater',
#       'vet',
#       'bus_public_transport',
#       'sports',
#       'metro',
#       'school',
#       'post_office',
#       'restaurant',
#       'drugstore',
#       'atm',
#       'tram',
#       'medic',
#       'kindergarten',
#       'train',
#       'shop']],
#     'seo': {'category_main_cb': 2,
#      'category_sub_cb': 37,
#      'category_type_cb': 2,
#      'locality': 'praha-suchdol-k-chumberku'},
#     'exclusively_at_rk': 0,
#     'category': 2,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/3062581068',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/3062581068',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False}},
#     'paid_logo': 0,
#     'locality': 'Praha 6 - Suchdol',
#     'has_video': False,
#     'advert_images_count': 30,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 2,
#     'hash_id': 3062581068,
#     'attractive_offer': 0,
#     'price': 40000,
#     'price_czk': {'value_raw': 40000,
#      'unit': 'za měsíc',
#      'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gQ_q/3Irdib.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gQ_q/3Irdib.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/3?category_main_cb=2&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=2'},
#      'self': {'href': '/cs/v2/estates/3062581068'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gQ_q/3Irdib.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gZ_r/GtKdcE.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jb/aJ1i92.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_Kr/JUijGU.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gS_q/PXYdZZ.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gU_p/qq3c74.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gQ_q/3Irdib.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Pronájem  rodinného domu 125\xa0m², pozemek 350\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.128623601667776, 'lon': 14.376557398332224},
#     'has_matterport_url': False},
#    {'labelsReleased': [['partly_furnished'], ['metro', 'atm']],
#     'has_panorama': 0,
#     'labels': ['Částečně vybavený',
#      'Metro 7 min. pěšky',
#      'Bankomat 6 min. pěšky'],
#     'is_auction': False,
#     'labelsAll': [['garage', 'partly_furnished'],
#      ['playground',
#       'small_shop',
#       'vet',
#       'candy_shop',
#       'theater',
#       'tavern',
#       'movies',
#       'natural_attraction',
#       'school',
#       'post_office',
#       'restaurant',
#       'metro',
#       'shop',
#       'train',
#       'tram',
#       'drugstore',
#       'medic',
#       'sports',
#       'atm',
#       'kindergarten',
#       'bus_public_transport']],
#     'seo': {'category_main_cb': 2,
#      'category_sub_cb': 37,
#      'category_type_cb': 2,
#      'locality': 'praha-stodulky-kecova'},
#     'exclusively_at_rk': 0,
#     'category': 2,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/3371693132',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/3371693132',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'Idealni-najemce-Brno-Zabrdovice',
#       'id': 16907,
#       'name': 'Ideální nájemce',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_E_I/EKrE4l.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 5 - Stodůlky',
#     'has_video': False,
#     'advert_images_count': 29,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 2,
#     'hash_id': 3371693132,
#     'attractive_offer': 0,
#     'price': 31000,
#     'price_czk': {'value_raw': 31000,
#      'unit': 'za měsíc',
#      'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gX_q/om5CCkl.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gX_q/om5CCkl.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/4?category_main_cb=2&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=2'},
#      'self': {'href': '/cs/v2/estates/3371693132'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gX_q/om5CCkl.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_Jg/0YBB9uP.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gV_s/ESSCCam.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gV_s/zUGCCan.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gV_s/tVMCCao.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jb/ghvB9dI.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_gX_q/om5CCkl.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Pronájem  rodinného domu 139\xa0m², pozemek 139\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.04265960166777, 'lon': 14.309941398332224},
#     'has_matterport_url': False},
#    {'labelsReleased': [[], ['post_office']],
#     'has_panorama': 0,
#     'labels': ['Pošta 6 min. pěšky'],
#     'is_auction': False,
#     'labelsAll': [['garage', 'cellar'],
#      ['playground',
#       'small_shop',
#       'candy_shop',
#       'vet',
#       'movies',
#       'tavern',
#       'theater',
#       'sports',
#       'atm',
#       'restaurant',
#       'shop',
#       'medic',
#       'train',
#       'post_office',
#       'school',
#       'metro',
#       'bus_public_transport',
#       'kindergarten',
#       'drugstore']],
#     'seo': {'category_main_cb': 2,
#      'category_sub_cb': 37,
#      'category_type_cb': 2,
#      'locality': 'praha-bechovice-vyjezdova'},
#     'exclusively_at_rk': 0,
#     'category': 2,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/21742668',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/21742668',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'Idealni-najemce-Brno-Zabrdovice',
#       'id': 16907,
#       'name': 'Ideální nájemce',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_E_I/EKrE4l.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 9 - Běchovice',
#     'has_video': False,
#     'advert_images_count': 23,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 2,
#     'hash_id': 21742668,
#     'attractive_offer': 0,
#     'price': 19000,
#     'price_czk': {'value_raw': 19000,
#      'unit': 'za měsíc',
#      'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QR_L6/yBhBTol.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QR_L6/yBhBTol.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/5?category_main_cb=2&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=2'},
#      'self': {'href': '/cs/v2/estates/21742668'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QR_L6/yBhBTol.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_Jh/R0bBTvc.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_KW/NzRBmL2.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_LZ/q91s4u.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QR_L6/ZvVBTom.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_Kt/uY7CmQ.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QR_L6/yBhBTol.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Pronájem  rodinného domu 124\xa0m², pozemek 770\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.07453460166777, 'lon': 14.629641398332224},
#     'has_matterport_url': False},
#    {'labelsReleased': [['basin'], []],
#     'has_panorama': 0,
#     'labels': ['Bazén'],
#     'is_auction': False,
#     'labelsAll': [['garage', 'parking_lots', 'basin', 'cellar'],
#      ['playground',
#       'small_shop',
#       'candy_shop',
#       'theater',
#       'tavern',
#       'vet',
#       'movies',
#       'natural_attraction',
#       'train',
#       'restaurant',
#       'post_office',
#       'metro',
#       'sports',
#       'kindergarten',
#       'shop',
#       'atm',
#       'school',
#       'drugstore',
#       'medic',
#       'tram',
#       'bus_public_transport']],
#     'seo': {'category_main_cb': 2,
#      'category_sub_cb': 37,
#      'category_type_cb': 2,
#      'locality': 'praha-ruzyne-nad-visnovkou'},
#     'exclusively_at_rk': 0,
#     'category': 2,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/108643916',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/108643916',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'ENGEL-VOLKERS-Praha-Smichov',
#       'id': 10628,
#       'name': 'ENGEL & VÖLKERS',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_H_H/g1qQpu.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 6 - Ruzyně',
#     'has_video': False,
#     'advert_images_count': 15,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 2,
#     'hash_id': 108643916,
#     'attractive_offer': 0,
#     'price': 59000,
#     'price_czk': {'value_raw': 59000,
#      'unit': 'za měsíc',
#      'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_Jz/6CWSjb.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_Jz/6CWSjb.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/6?category_main_cb=2&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=2'},
#      'self': {'href': '/cs/v2/estates/108643916'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_Jz/6CWSjb.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jg/Ki3iuT.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_Jh/wvaBeEr.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_Jz/dhHSjc.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_Jz/d9iSjd.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_Jh/PTrBeEs.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_Jz/6CWSjb.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Pronájem  rodinného domu 236\xa0m², pozemek 650\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.07071260166777, 'lon': 14.324121398332224},
#     'has_matterport_url': False},
#    {'labelsReleased': [['after_reconstruction'], []],
#     'has_panorama': 0,
#     'labels': ['Po rekonstrukci'],
#     'is_auction': False,
#     'labelsAll': [['after_reconstruction',
#       'garage',
#       'parking_lots',
#       'not_furnished',
#       'cellar'],
#      ['playground',
#       'small_shop',
#       'candy_shop',
#       'vet',
#       'theater',
#       'tavern',
#       'movies',
#       'natural_attraction',
#       'kindergarten',
#       'sports',
#       'metro',
#       'shop',
#       'train',
#       'restaurant',
#       'atm',
#       'post_office',
#       'tram',
#       'drugstore',
#       'school',
#       'bus_public_transport',
#       'medic']],
#     'seo': {'category_main_cb': 2,
#      'category_sub_cb': 37,
#      'category_type_cb': 2,
#      'locality': 'praha-ruzyne-huberova'},
#     'exclusively_at_rk': 0,
#     'category': 2,
#     'has_floor_plan': 0,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/3739182668',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/3739182668',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'ENGEL-VOLKERS-Praha-Smichov',
#       'id': 10628,
#       'name': 'ENGEL & VÖLKERS',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_H_H/g1qQpu.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 6 - Ruzyně',
#     'has_video': False,
#     'advert_images_count': 18,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 2,
#     'hash_id': 3739182668,
#     'attractive_offer': 0,
#     'price': 38000,
#     'price_czk': {'value_raw': 38000,
#      'unit': 'za měsíc',
#      'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_Jh/jwrBeDy.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_Jh/jwrBeDy.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/7?category_main_cb=2&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=2'},
#      'self': {'href': '/cs/v2/estates/3739182668'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_Jh/jwrBeDy.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jg/0VxitN.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jb/fB3Bdqv.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_Kt/HQYNBq.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_Kt/sVWNBr.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QR_L6/VriBeCK.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_Jh/jwrBeDy.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Pronájem  rodinného domu 170\xa0m², pozemek 430\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.07403860166777, 'lon': 14.327602398332223},
#     'has_matterport_url': False},
#    {'labelsReleased': [['furnished'], []],
#     'has_panorama': 0,
#     'labels': ['Vybavený'],
#     'is_auction': False,
#     'labelsAll': [['garage', 'parking_lots', 'furnished'],
#      ['playground',
#       'small_shop',
#       'tavern',
#       'candy_shop',
#       'vet',
#       'theater',
#       'movies',
#       'natural_attraction',
#       'sports',
#       'train',
#       'school',
#       'atm',
#       'medic',
#       'kindergarten',
#       'drugstore',
#       'post_office',
#       'tram',
#       'bus_public_transport',
#       'restaurant',
#       'metro',
#       'shop']],
#     'seo': {'category_main_cb': 2,
#      'category_sub_cb': 37,
#      'category_type_cb': 2,
#      'locality': 'praha-velka-chuchle-mrkosova'},
#     'exclusively_at_rk': 0,
#     'category': 2,
#     'has_floor_plan': 0,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/2827625548',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/2827625548',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'LEXXUS-NORTON-Praha-Nove-Mesto',
#       'id': 578,
#       'name': 'LEXXUS NORTON',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_gY_t/4kQC77.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 5 - Velká Chuchle',
#     'has_video': False,
#     'advert_images_count': 14,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 2,
#     'hash_id': 2827625548,
#     'attractive_offer': 0,
#     'price': 62000,
#     'price_czk': {'value_raw': 62000,
#      'unit': 'za měsíc',
#      'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QR_L6/1Q3BtA3.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QR_L6/1Q3BtA3.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/8?category_main_cb=2&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=2'},
#      'self': {'href': '/cs/v2/estates/2827625548'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QR_L6/1Q3BtA3.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jb/KRiBskt.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_Ky/3JPWbV.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_KW/zpmCBhH.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_Ku/2HiGH3.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_Ky/i27WbX.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QR_L6/1Q3BtA3.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Pronájem  rodinného domu 138\xa0m², pozemek 190\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.000170601667776, 'lon': 14.389070398332224},
#     'has_matterport_url': False},
#    {'labelsReleased': [['new_building', 'basin'], []],
#     'has_panorama': 0,
#     'labels': ['Novostavba', 'Bazén'],
#     'is_auction': False,
#     'labelsAll': [['new_building',
#       'garage',
#       'parking_lots',
#       'basin',
#       'not_furnished'],
#      ['playground',
#       'small_shop',
#       'tavern',
#       'candy_shop',
#       'vet',
#       'theater',
#       'restaurant',
#       'drugstore',
#       'bus_public_transport',
#       'sports',
#       'school',
#       'post_office',
#       'shop',
#       'tram',
#       'kindergarten',
#       'train',
#       'medic',
#       'atm',
#       'metro']],
#     'seo': {'category_main_cb': 2,
#      'category_sub_cb': 37,
#      'category_type_cb': 2,
#      'locality': 'praha-predni-kopanina-nove-domy'},
#     'exclusively_at_rk': 0,
#     'category': 2,
#     'has_floor_plan': 0,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/4008843084',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/4008843084',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'LEXXUS-NORTON-Praha-Nove-Mesto',
#       'id': 578,
#       'name': 'LEXXUS NORTON',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_gY_t/4kQC77.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 6 - Přední Kopanina',
#     'has_video': False,
#     'advert_images_count': 19,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 2,
#     'hash_id': 4008843084,
#     'attractive_offer': 0,
#     'price': 54000,
#     'price_czk': {'value_raw': 54000,
#      'unit': 'za měsíc',
#      'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jg/6kvxoR.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jg/6kvxoR.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/9?category_main_cb=2&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=2'},
#      'self': {'href': '/cs/v2/estates/4008843084'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jg/6kvxoR.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_Jz/YeJhfk.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_Jz/Odqhfl.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_LZ/2wCBISi.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_Ku/8H6GHz.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_Jy/DyJBsot.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jg/6kvxoR.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Pronájem  rodinného domu 284\xa0m², pozemek 1\xa0036\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.111701601667775, 'lon': 14.302597398332225},
#     'has_matterport_url': False},
#    {'labelsReleased': [[], []],
#     'has_panorama': 0,
#     'labels': [],
#     'is_auction': False,
#     'labelsAll': [['garage', 'parking_lots', 'not_furnished', 'cellar'],
#      ['playground',
#       'theater',
#       'small_shop',
#       'candy_shop',
#       'vet',
#       'tavern',
#       'movies',
#       'natural_attraction',
#       'sports',
#       'train',
#       'kindergarten',
#       'restaurant',
#       'post_office',
#       'drugstore',
#       'tram',
#       'shop',
#       'metro',
#       'atm',
#       'school',
#       'bus_public_transport',
#       'medic']],
#     'seo': {'category_main_cb': 2,
#      'category_sub_cb': 39,
#      'category_type_cb': 2,
#      'locality': 'praha-stodulky-5--maje'},
#     'exclusively_at_rk': 0,
#     'category': 2,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/3019277388',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/3019277388',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'LEXXUS-NORTON-Praha-Nove-Mesto',
#       'id': 578,
#       'name': 'LEXXUS NORTON',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_gY_t/4kQC77.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 5 - Stodůlky',
#     'has_video': False,
#     'advert_images_count': 16,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 2,
#     'hash_id': 3019277388,
#     'attractive_offer': 0,
#     'price': 68000,
#     'price_czk': {'value_raw': 68000,
#      'unit': 'za měsíc',
#      'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jb/D92BkZl.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jb/D92BkZl.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/10?category_main_cb=2&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=2'},
#      'self': {'href': '/cs/v2/estates/3019277388'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jb/D92BkZl.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_Kt/yD8Tv9.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_LZ/3yRBACX.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_Jz/SXPZOr.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_LZ/Ur4BACY.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_LZ/kqQBACZ.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jb/D92BkZl.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Pronájem  vily 284\xa0m², pozemek 800\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.05667860166778, 'lon': 14.330839398332223},
#     'has_matterport_url': False},
#    {'labelsReleased': [['basin'], ['school', 'post_office']],
#     'has_panorama': 0,
#     'labels': ['Bazén', 'Škola 3 min. pěšky', 'Pošta 3 min. pěšky'],
#     'is_auction': False,
#     'labelsAll': [['garage', 'parking_lots', 'basin', 'not_furnished'],
#      ['playground',
#       'vet',
#       'tavern',
#       'candy_shop',
#       'movies',
#       'small_shop',
#       'theater',
#       'sightseeing',
#       'sports',
#       'kindergarten',
#       'medic',
#       'school',
#       'metro',
#       'shop',
#       'bus_public_transport',
#       'drugstore',
#       'tram',
#       'post_office',
#       'restaurant',
#       'atm',
#       'train']],
#     'seo': {'category_main_cb': 2,
#      'category_sub_cb': 37,
#      'category_type_cb': 2,
#      'locality': 'praha-troja-trojska'},
#     'exclusively_at_rk': 0,
#     'category': 2,
#     'has_floor_plan': 0,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/1463604300',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/1463604300',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'LEXXUS-NORTON-Praha-Nove-Mesto',
#       'id': 578,
#       'name': 'LEXXUS NORTON',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_gY_t/4kQC77.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 7 - Troja',
#     'has_video': False,
#     'advert_images_count': 11,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 2,
#     'hash_id': 1463604300,
#     'attractive_offer': 0,
#     'price': 114000,
#     'price_czk': {'value_raw': 114000,
#      'unit': 'za měsíc',
#      'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_Kx/D6mBzQG.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_Kx/D6mBzQG.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/11?category_main_cb=2&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=2'},
#      'self': {'href': '/cs/v2/estates/1463604300'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_Kx/D6mBzQG.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_Jy/IWuBFYu.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_Jy/GlbCASN.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_KW/jmrBYQt.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_LZ/SkAe4a.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jb/CllBFW4.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_Kx/D6mBzQG.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Pronájem  rodinného domu 241\xa0m², pozemek 772\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.11061460166778, 'lon': 14.426957398332224},
#     'has_matterport_url': False},
#    {'labelsReleased': [[], []],
#     'has_panorama': 0,
#     'labels': [],
#     'is_auction': False,
#     'labelsAll': [['garage', 'parking_lots', 'not_furnished'],
#      ['playground',
#       'candy_shop',
#       'small_shop',
#       'movies',
#       'tavern',
#       'theater',
#       'vet',
#       'kindergarten',
#       'bus_public_transport',
#       'sports',
#       'restaurant',
#       'train',
#       'post_office',
#       'school',
#       'metro',
#       'drugstore',
#       'medic',
#       'atm',
#       'tram',
#       'shop']],
#     'seo': {'category_main_cb': 2,
#      'category_sub_cb': 39,
#      'category_type_cb': 2,
#      'locality': 'praha-suchdol-k-chumberku'},
#     'exclusively_at_rk': 0,
#     'category': 2,
#     'has_floor_plan': 0,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/1792197708',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/1792197708',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'LEXXUS-NORTON-Praha-Nove-Mesto',
#       'id': 578,
#       'name': 'LEXXUS NORTON',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_gY_t/4kQC77.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 6 - Suchdol',
#     'has_video': False,
#     'advert_images_count': 24,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 2,
#     'hash_id': 1792197708,
#     'attractive_offer': 0,
#     'price': 40000,
#     'price_czk': {'value_raw': 40000,
#      'unit': 'za měsíc',
#      'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_Kx/iKkBEi5.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_Kx/iKkBEi5.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/12?category_main_cb=2&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=2'},
#      'self': {'href': '/cs/v2/estates/1792197708'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_Kx/iKkBEi5.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jc/bwgU6p.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_Kx/QOFBEi6.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jc/Fw6U6q.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jc/pyNU6r.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_Jh/ENrVHV.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QP_Kx/iKkBEi5.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Pronájem  vily 124\xa0m², pozemek 350\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.12826460166777, 'lon': 14.376998398332224},
#     'has_matterport_url': False},
#    {'labelsReleased': [[], ['tram']],
#     'has_panorama': 0,
#     'labels': ['Tramvaj 4 min. pěšky'],
#     'is_auction': False,
#     'labelsAll': [['garage', 'parking_lots', 'not_furnished'],
#      ['small_shop',
#       'movies',
#       'candy_shop',
#       'tavern',
#       'playground',
#       'vet',
#       'theater',
#       'natural_attraction',
#       'sports',
#       'shop',
#       'kindergarten',
#       'atm',
#       'metro',
#       'train',
#       'bus_public_transport',
#       'drugstore',
#       'medic',
#       'restaurant',
#       'post_office',
#       'school',
#       'tram']],
#     'seo': {'category_main_cb': 2,
#      'category_sub_cb': 37,
#      'category_type_cb': 2,
#      'locality': 'praha-stodulky-hlusickova'},
#     'exclusively_at_rk': 0,
#     'category': 2,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/2855547980',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/2855547980',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'LEXXUS-NORTON-Praha-Nove-Mesto',
#       'id': 578,
#       'name': 'LEXXUS NORTON',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_gY_t/4kQC77.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 5 - Stodůlky',
#     'has_video': False,
#     'advert_images_count': 14,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 2,
#     'hash_id': 2855547980,
#     'attractive_offer': 0,
#     'price': 45000,
#     'price_czk': {'value_raw': 45000,
#      'unit': 'za měsíc',
#      'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_LZ/Xkvxr9.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_LZ/Xkvxr9.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/13?category_main_cb=2&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=2'},
#      'self': {'href': '/cs/v2/estates/2855547980'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_LZ/Xkvxr9.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_KW/XivBq6a.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_Jy/Om7BYIt.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jb/bodBYCp.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QR_L6/T9rBYah.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QN_Jz/9meM76.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_LZ/Xkvxr9.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Pronájem  rodinného domu 208\xa0m², pozemek 378\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.056864601667776, 'lon': 14.324663398332223},
#     'has_matterport_url': False},
#    {'labelsReleased': [[], []],
#     'has_panorama': 0,
#     'labels': [],
#     'is_auction': False,
#     'labelsAll': [['garage', 'parking_lots', 'not_furnished', 'cellar'],
#      ['playground',
#       'small_shop',
#       'candy_shop',
#       'theater',
#       'vet',
#       'tavern',
#       'movies',
#       'natural_attraction',
#       'school',
#       'bus_public_transport',
#       'train',
#       'tram',
#       'kindergarten',
#       'medic',
#       'drugstore',
#       'shop',
#       'metro',
#       'atm',
#       'sports',
#       'post_office',
#       'restaurant']],
#     'seo': {'category_main_cb': 2,
#      'category_sub_cb': 39,
#      'category_type_cb': 2,
#      'locality': 'praha-ruzyne-huberova'},
#     'exclusively_at_rk': 0,
#     'category': 2,
#     'has_floor_plan': 0,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/2457019980',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/2457019980',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'LEXXUS-NORTON-Praha-Nove-Mesto',
#       'id': 578,
#       'name': 'LEXXUS NORTON',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_gY_t/4kQC77.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 6 - Ruzyně',
#     'has_video': False,
#     'advert_images_count': 14,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 2,
#     'hash_id': 2457019980,
#     'attractive_offer': 0,
#     'price': 38000,
#     'price_czk': {'value_raw': 38000,
#      'unit': 'za měsíc',
#      'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_Jh/4oOfDn.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_Jh/4oOfDn.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/14?category_main_cb=2&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=2'},
#      'self': {'href': '/cs/v2/estates/2457019980'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_Jh/4oOfDn.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_Jy/JPSeq3.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_KW/yLqxne.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_Jy/bFIeq4.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_LX/KmXBU01.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_Jy/cEceq5.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_Jh/4oOfDn.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Pronájem  vily 170\xa0m², pozemek 430\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.07395460166777, 'lon': 14.327376398332223},
#     'has_matterport_url': False},
#    {'labelsReleased': [['basin'], []],
#     'has_panorama': 0,
#     'labels': ['Bazén'],
#     'is_auction': False,
#     'labelsAll': [['garage', 'parking_lots', 'basin', 'not_furnished'],
#      ['small_shop',
#       'movies',
#       'candy_shop',
#       'playground',
#       'theater',
#       'vet',
#       'tavern',
#       'natural_attraction',
#       'restaurant',
#       'post_office',
#       'sports',
#       'kindergarten',
#       'drugstore',
#       'atm',
#       'shop',
#       'bus_public_transport',
#       'metro',
#       'tram',
#       'school',
#       'train',
#       'medic']],
#     'seo': {'category_main_cb': 2,
#      'category_sub_cb': 39,
#      'category_type_cb': 2,
#      'locality': 'praha-ruzyne-nad-visnovkou'},
# ...
#      'iterator': {'href': '/cs/v2/estate-iterator/16?category_main_cb=2&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=2'},
#      'self': {'href': '/cs/v2/estates/3286541900'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jg/nFoMmO.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_KW/S49BaUh.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QR_L6/SfABHuy.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_Jy/D8nBHf4.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_Jy/6X1BHf5.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_Jy/qhJBHf6.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jg/nFoMmO.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Pronájem  vily 259\xa0m², pozemek 1\xa0559\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.05932560166777, 'lon': 14.396655398332223},
#     'has_matterport_url': False},
#    {'labelsReleased': [['new_building', 'partly_furnished'], []],
#     'has_panorama': 0,
#     'labels': ['Novostavba', 'Částečně vybavený'],
#     'is_auction': False,
#     'labelsAll': [['new_building', 'garage', 'partly_furnished'],
#      ['playground',
#       'small_shop',
#       'candy_shop',
#       'tavern',
#       'theater',
#       'vet',
#       'movies',
#       'sports',
#       'post_office',
#       'restaurant',
#       'drugstore',
#       'atm',
#       'tram',
#       'bus_public_transport',
#       'shop',
#       'school',
#       'medic',
#       'metro',
#       'kindergarten',
#       'train']],
#     'seo': {'category_main_cb': 2,
#      'category_sub_cb': 37,
#      'category_type_cb': 2,
#      'locality': 'praha-brezineves-za-sadem'},
#     'exclusively_at_rk': 1,
#     'category': 2,
#     'has_floor_plan': 0,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/2613978188',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/2613978188',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False}},
#     'paid_logo': 0,
#     'locality': 'Praha 8 - Březiněves',
#     'has_video': False,
#     'advert_images_count': 20,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 2,
#     'hash_id': 2613978188,
#     'attractive_offer': 0,
#     'price': 29000,
#     'price_czk': {'value_raw': 29000,
#      'unit': 'za měsíc',
#      'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_LZ/4sOBIO2.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_LZ/4sOBIO2.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/17?category_main_cb=2&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=2'},
#      'self': {'href': '/cs/v2/estates/2613978188'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_LZ/4sOBIO2.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_Jh/FqkBs3w.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_Jh/HJSBs3x.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_Jh/c2BBs3y.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jg/Ddfxki.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_Ku/deWGD2.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_LZ/4sOBIO2.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Pronájem  rodinného domu 111\xa0m², pozemek 363\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.16024760166778, 'lon': 14.489182398332224},
#     'has_matterport_url': False},
#    {'labelsReleased': [[], ['school']],
#     'has_panorama': 0,
#     'labels': ['Škola 7 min. pěšky'],
#     'is_auction': False,
#     'labelsAll': [['parking_lots', 'not_furnished', 'cellar'],
#      ['small_shop',
#       'theater',
#       'vet',
#       'playground',
#       'tavern',
#       'candy_shop',
#       'movies',
#       'natural_attraction',
#       'train',
#       'kindergarten',
#       'medic',
#       'restaurant',
#       'tram',
#       'school',
#       'shop',
#       'atm',
#       'post_office',
#       'sports',
#       'bus_public_transport',
#       'metro',
#       'drugstore']],
#     'seo': {'category_main_cb': 2,
#      'category_sub_cb': 37,
#      'category_type_cb': 2,
#      'locality': 'praha-strizkov-chrastavska'},
#     'exclusively_at_rk': 0,
#     'category': 2,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/4193728332',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/4193728332',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False}},
#     'paid_logo': 0,
#     'locality': 'Praha 9 - Střížkov',
#     'has_video': False,
#     'advert_images_count': 23,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 2,
#     'hash_id': 4193728332,
#     'attractive_offer': 0,
#     'price': 22000,
#     'price_czk': {'value_raw': 22000,
#      'unit': 'za měsíc',
#      'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_JZ/CzKe3P.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_JZ/CzKe3P.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/18?category_main_cb=2&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=2'},
#      'self': {'href': '/cs/v2/estates/4193728332'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_JZ/CzKe3P.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gT_r/KtDwuW.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_LU/glse1N.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QL_Jw/WVQevF.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_gX_p/VXFwve.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_JZ/J0ye3Q.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_JZ/CzKe3P.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Pronájem  rodinného domu 77\xa0m², pozemek 77\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.112967601667776, 'lon': 14.489631398332223},
#     'has_matterport_url': False},
#    {'labelsReleased': [['new_building', 'low_energy'], []],
#     'has_panorama': 0,
#     'labels': ['Novostavba', 'Nízkoenergetický'],
#     'is_auction': False,
#     'labelsAll': [['new_building', 'garage', 'parking_lots', 'low_energy'],
#      ['playground',
#       'candy_shop',
#       'vet',
#       'small_shop',
#       'tavern',
#       'movies',
#       'theater',
#       'post_office',
#       'atm',
#       'restaurant',
#       'kindergarten',
#       'train',
#       'shop',
#       'school',
#       'drugstore',
#       'bus_public_transport',
#       'metro',
#       'tram',
#       'medic',
#       'sports']],
#     'seo': {'category_main_cb': 2,
#      'category_sub_cb': 37,
#      'category_type_cb': 2,
#      'locality': 'praha-letnany-veselska'},
#     'exclusively_at_rk': 0,
#     'category': 2,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/4192109644',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/4192109644',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False}},
#     'paid_logo': 0,
#     'locality': 'Praha 9 - Letňany',
#     'has_video': False,
#     'advert_images_count': 26,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 2,
#     'hash_id': 4192109644,
#     'attractive_offer': 0,
#     'price': 0,
#     'price_czk': {'value_raw': 0, 'unit': 'za měsíc', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_LW/nogUbk.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_LW/nogUbk.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/19?category_main_cb=2&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=2'},
#      'self': {'href': '/cs/v2/estates/4192109644'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_LW/nogUbk.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QR_L6/2fhzfl.jpeg?fl=rot,270,0|res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_KW/3olBIOj.jpeg?fl=rot,270,0|res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_LZ/3VTOw2.jpeg?fl=rot,270,0|res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_KW/1UrBIOk.jpeg?fl=rot,270,0|res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_KW/CINBIOl.jpeg?fl=rot,270,0|res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QQ_LW/nogUbk.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': True,
#     'name': 'Pronájem  rodinného domu 99\xa0m², pozemek 298\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.13542160166777, 'lon': 14.524724398332223},
#     'has_matterport_url': False},
#    {'labelsReleased': [[], ['school']],
#     'has_panorama': 0,
#     'labels': ['Škola 4 min. pěšky'],
#     'is_auction': False,
#     'labelsAll': [['garage', 'parking_lots', 'not_furnished', 'cellar'],
#      ['playground',
#       'natural_attraction',
#       'candy_shop',
#       'small_shop',
#       'tavern',
#       'theater',
#       'vet',
#       'movies',
#       'sightseeing',
#       'sports',
#       'bus_public_transport',
#       'post_office',
#       'restaurant',
#       'drugstore',
#       'atm',
#       'train',
#       'school',
#       'tram',
#       'medic',
#       'kindergarten',
#       'metro',
#       'shop']],
#     'seo': {'category_main_cb': 2,
#      'category_sub_cb': 37,
#      'category_type_cb': 2,
#      'locality': 'praha-jinonice-brezanecka'},
#     'exclusively_at_rk': 0,
#     'category': 2,
#     'has_floor_plan': 0,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/4274521932',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/4274521932',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'RK-MoWio-s-r-o-Praha-Dejvice',
#       'id': 46856,
#       'name': 'RK MoWio s.r.o.',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_gR_n/vpjNp.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 5 - Jinonice',
#     'has_video': False,
#     'advert_images_count': 15,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 2,
#     'hash_id': 4274521932,
#     'attractive_offer': 0,
#     'price': 45000,
#     'price_czk': {'value_raw': 45000,
#      'unit': 'za měsíc',
#      'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_Jh/SGeBYY1.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_Jh/SGeBYY1.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/20?category_main_cb=2&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=2'},
#      'self': {'href': '/cs/v2/estates/4274521932'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_Jh/SGeBYY1.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QR_L6/HEaBYVH.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QM_KW/YvCBq1j.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QK_Jg/LoCdEK.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QO_Kt/6FBHTr.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_QI_Jb/7rIBX68.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_QJ_Jh/SGeBYY1.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Pronájem  rodinného domu 121\xa0m², pozemek 324\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.048472601667775, 'lon': 14.357465398332224},
#     'has_matterport_url': False}],
#   'is_saved': {'email_notification': False,
#    'notification_advert_count': 0,
#    'stack_id': 0,
#    'push_notification': False,
#    '_links': {'self': {'href': '/cs/v2/stacks'}},
#    'removed': False,
#    'saved': False},
#   'not_precise_location_count': {'result_size_auction': 0,
#    'result_size': 110,
#    '_links': {'self': {'profile': '/estates/count/doc',
#      'href': '/cs/v2/estates/count?category_main_cb=2&locality_region_id=10&category_type_cb=3',
#      'title': 'Estate count'}}}},
#  'filterLabels': [],
#  'title': 'Domy k pronájmu Praha',
#  'filter': {'category_main_cb': '2',
#   'suggested_districtId': -1,
#   'locality_region_id': '10',
#   'category_type_cb': '2',
#   'suggested_regionId': -1},
#  '_links': {'self': {'href': '/cs/v2/estates?category_main_cb=2&locality_region_id=10&category_type_cb=2&page=1'},
#   'clusters_with_bounding_box_of_first_10': {'href': '/cs/v2/clusters?category_main_cb=2&locality_region_id=10&category_type_cb=2&per_page60=&leftBottomBounding=14.3025973983|50.0001706017&page=1&rightTopBounding=14.6296413983|50.1286236017'},
#   'rss': {'href': '/api/cs/v2/estates/rss?category_main_cb=2&category_type_cb=2&locality_region_id=10&suggested_regionId=-1&suggested_districtId=-1'}},
#  'locality': 'okres Praha 5',
#  'locality_dativ': 'na Praze 5',
#  'logged_in': False,
#  'per_page': 20,
#  'category_instrumental': 'výběrem či pronájmem domu',
#  'page': 1,
#  'filterLabels2': {'something_more3_3310': 'elevator',
#   'something_more1_3120': 'cellar',
#   'something_more1_3100': 'loggia',
#   'furnished_1': 'furnished',
#   'furnished_2': 'partly_furnished',
#   'furnished_3': 'not_furnished',
#   'building_condition_9': 'after_reconstruction',
#   'something_more2_3150': 'garage',
#   'something_more2_3130': 'basin',
#   'ownership_1': 'personal',
#   'ownership_3': 'state',
#   'ownership_2': 'collective',
#   'something_more3_1820': 'easy_access',
#   'energy_efficiency_rating_search_7': 'energy_rating_g',
#   'energy_efficiency_rating_search_6': 'energy_rating_f',
#   'energy_efficiency_rating_search_5': 'energy_rating_e',
#   'energy_efficiency_rating_search_4': 'energy_rating_d',
#   'energy_efficiency_rating_search_3': 'energy_rating_c',
#   'energy_efficiency_rating_search_2': 'energy_rating_b',
#   'energy_efficiency_rating_search_1': 'energy_rating_a',
#   'something_more1_3110': 'terrace',
#   'building_condition_6': 'new_building',
#   'something_more1_3090': 'balcony',
#   'building_condition_4': 'in_construction',
#   'building_type_search_3': 'other_sigular',
#   'something_more2_3120': 'cellar',
#   'building_type_search_1': 'panel',
#   'something_more2_3140': 'parking_lots',
#   'something_more1_200222': 'garden',
#   'building_type_search_2': 'brick'}}

# %% [markdown]
# ### 1b. Create a function converting sreality json data into pandas dataframe

# %%
def sreality_to_json(sreality_json):
    return pd.json_normalize(sreality_json)

# %% [markdown]
# ### 1c. link function `1b` into function `1a`

# %%
def sreality_to_json(reality):
    def sreality(category_main, category_type, category_region, page):
        mains = {'flat':1, 'house':2, 'land':3}
        type = {"sell":1, "rent":2}
        location = {"Praha":10, "Brno":14}

        base_url = f'https://www.sreality.cz/api/cs/v2/estates?category_main_cb={mains[category_main]}&category_type_cb={type[category_type]}&locality_region_id={location[category_region]}&per_page60&page={page}'

        try:
            r = requests.get(base_url)
            if r.ok:
                return r.json()
        except:
            print("There was an erron in request.")

    sreality("house", "rent", "Praha", 1)
    return pd.json_normalize(sreality_json)

# %% [markdown]
# ### 1c. Combining multiple requests into single df
#
# * Function should parametrize:
#     * `start_page` and `end_page`
#     * request parameters
# * construct a list of individual request dfs
# * then feed it into `pd.concat` function

# %% [markdown]
# ## Task 2: Cleaning data
#
# ### 2a. Filter columns
# * filter only columns: `['locality', 'price', 'name', 'gps','hash_id','labelsAll','exclusively_at_rk']`
# * use `.copy()` to avoid `SettingWithCopyWarning` later

# %% [markdown]
# ### 2b: GPS
# * Convert dictionary in `gps` column into two columns - `lat` and `lon`
# * use apply function on gps column
# * Note apply can return multiple columns

# %% [markdown]
# ### 2b. Get flat type from name
# * Name is always represented by string `Prodej bytu [type of flat] [Area] m^2`
# * try picking third word in string
# * check meaningfulness using `.value_counts()`

# %%
def get_third_word(x):
    return x.split(" ")[2]

clean["name"].apply(get_third_word)

# %% [markdown]
# ### 2c. Get area from name
# * Naive: select the word before last word
# * Then try navigating using the index of `'m²'`
# * if this also fail, then you will need to use regex

# %% [markdown]
# ## Task 3 (Homework): Convert column`labelsAll` into boolean variables
#
# ### Task 3a. Get all possible label names
# * deal with nested-list structure
# * Hint: try sum the whole column to get a nested list of lists.
# * Then flatten the nested list (2D to 1D)
# * Finally keep only unique elements

# %% [markdown]
# ### 4b. Test existence of label `cellar` for offers
# * again deal with nested list of list structure
# * write generic function `test_existence_of_label(offer_labels,label)`

# %% [markdown]
# ### 4c. Test existence of all possible labels
# * use apply returning series with all labels
